# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model="gemini-pro",
    temperature=0,
    max_tokens=None,
    timeout=100,
    max_retries=2
    )

# %%
ai_msg = llm.invoke("인프런에는 어떤 강의들이 있어?")
# Out:
# ---------------------------------------------------------------------------
# _InactiveRpcError                         Traceback (most recent call last)
# File ~/.pyenv/versions/3.11.11/envs/llm-application/lib/python3.11/site-packages/google/api_core/grpc_helpers.py:76, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      75 try:
# ---> 76     return callable_(*args, **kwargs)
#      77 except grpc.RpcError as exc:
#
# File ~/.pyenv/versions/3.11.11/envs/llm-application/lib/python3.11/site-packages/grpc/_interceptor.py:277, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     268 def __call__(
#     269     self,
#     270     request: Any,
#    (...)    275     compression: Optional[grpc.Compression] = None,
#     276 ) -> Any:
# --> 277     response, ignored_call = self._with_call(
#     278         request,
#     279         timeout=timeout,
#     280         metadata=metadata,
#     281         credentials=credentials,
#     282         wait_for_ready=wait_for_ready,
#     283         compression=compression,
#     284     )
#     285     return response
#
# File ~/.pyenv/versions/3.11.11/envs/llm-application/lib/python3.11/site-packages/grpc/_interceptor.py:332, in _UnaryUnaryMultiCallable._with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     329 call = self._interceptor.intercept_unary_unary(
#     330     continuation, client_call_details, request
#     331 )
# --> 332 return call.result(), call
#
# File ~/.pyenv/versions/3.11.11/envs/llm-application/lib/python3.11/site-packages/grpc/_channel.py:440, in _InactiveRpcError.result(self, timeout)
#     439 """See grpc.Future.result."""
# --> 440 raise self
#
# File ~/.pyenv/versions/3.11.11/envs/llm-application/lib/python3.11/site-packages/grpc/_interceptor.py:315, in _UnaryUnaryMultiCallable._with_call.<locals>.continuation(new_details, request)
#     314 try:
# --> 315     response, call = self._thunk(new_method).with_call(
#     316         request,
#     317         timeout=new_timeout,
#     318         metadata=new_metadata,
#     319         credentials=new_credentials,
#     320         wait_for_ready=new_wait_for_ready,
#     321         compression=new_compression,
#     322     )
#     323     return _UnaryOutcome(response, call)
#
# File ~/.pyenv/versions/3.11.11/envs/llm-application/lib/python3.11/site-packages/grpc/_channel.py:1198, in _UnaryUnaryMultiCallable.with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1192 (
#    1193     state,
#    1194     call,
#    1195 ) = self._blocking(
#    1196     request, timeout, metadata, credentials, wait_for_ready, compression
#    1197 )
# -> 1198 return _end_unary_response_blocking(state, call, True, None)
#
# File ~/.pyenv/versions/3.11.11/envs/llm-application/lib/python3.11/site-packages/grpc/_channel.py:1006, in _end_unary_response_blocking(state, call, with_call, deadline)
#    1005 else:
# -> 1006     raise _InactiveRpcError(state)
#
# _InactiveRpcError: <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNAVAILABLE
# 	details = "DNS resolution failed for generativelanguage.googleapis.com:443: C-ares status is not ARES_SUCCESS qtype=A name=generativelanguage.googleapis.com is_balancer=0: DNS query cancelled"
# 	debug_error_string = "UNKNOWN:Error received from peer  {created_time:"2025-04-04T14:25:26.117465+09:00", grpc_status:14, grpc_message:"DNS resolution failed for generativelanguage.googleapis.com:443: C-ares status is not ARES_SUCCESS qtype=A name=generativelanguage.googleapis.com is_balancer=0: DNS query cancelled"}"
# >
#
# The above exception was the direct cause of the following exception:
#
# ServiceUnavailable                        Traceback (most recent call last)
# File ~/.pyenv/versions/3.11.11/envs/llm-application/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py:144, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     143 try:
# --> 144     result = target()
#     145     if inspect.isawaitable(result):
#
# File ~/.pyenv/versions/3.11.11/envs/llm-application/lib/python3.11/site-packages/google/api_core/timeout.py:130, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     128     kwargs["timeout"] = remaining_timeout
# --> 130 return func(*args, **kwargs)
#
# File ~/.pyenv/versions/3.11.11/envs/llm-application/lib/python3.11/site-packages/google/api_core/grpc_helpers.py:78, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      77 except grpc.RpcError as exc:
# ---> 78     raise exceptions.from_grpc_error(exc) from exc
#
# ServiceUnavailable: 503 DNS resolution failed for generativelanguage.googleapis.com:443: C-ares status is not ARES_SUCCESS qtype=A name=generativelanguage.googleapis.com is_balancer=0: DNS query cancelled
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 ai_msg = llm.invoke("인프런에는 어떤 강의들이 있어?")
#
# File ~/.pyenv/versions/3.11.11/envs/llm-application/lib/python3.11/site-packages/langchain_google_genai/chat_models.py:1022, in ChatGoogleGenerativeAI.invoke(self, input, config, code_execution, stop, **kwargs)
#    1017     else:
#    1018         raise ValueError(
#    1019             "Tools are already defined." "code_execution tool can't be defined"
#    1020         )
# -> 1022 return super().invoke(input, config, stop=stop, **kwargs)
#
# File ~/.pyenv/versions/3.11.11/envs/llm-application/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:310, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     298 @override
#     299 def invoke(
#     300     self,
#    (...)    305     **kwargs: Any,
#     306 ) -> BaseMessage:
#     307     config = ensure_config(config)
#     308     return cast(
#     309         "ChatGeneration",
# --> 310         self.generate_prompt(
#     311             [self._convert_input(input)],
#     312             stop=stop,
#     313             callbacks=config.get("callbacks"),
#     314             tags=config.get("tags"),
#     315             metadata=config.get("metadata"),
#     316             run_name=config.get("run_name"),
#     317             run_id=config.pop("run_id", None),
#     318             **kwargs,
#     319         ).generations[0][0],
#     320     ).message
#
# File ~/.pyenv/versions/3.11.11/envs/llm-application/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:859, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     850 @override
#     851 def generate_prompt(
#     852     self,
#    (...)    856     **kwargs: Any,
#     857 ) -> LLMResult:
#     858     prompt_messages = [p.to_messages() for p in prompts]
# --> 859     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/.pyenv/versions/3.11.11/envs/llm-application/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:694, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     691 for i, m in enumerate(messages):
#     692     try:
#     693         results.append(
# --> 694             self._generate_with_cache(
#     695                 m,
#     696                 stop=stop,
#     697                 run_manager=run_managers[i] if run_managers else None,
#     698                 **kwargs,
#     699             )
#     700         )
#     701     except BaseException as e:
#     702         if run_managers:
#
# File ~/.pyenv/versions/3.11.11/envs/llm-application/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:925, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     923 else:
#     924     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 925         result = self._generate(
#     926             messages, stop=stop, run_manager=run_manager, **kwargs
#     927         )
#     928     else:
#     929         result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/.pyenv/versions/3.11.11/envs/llm-application/lib/python3.11/site-packages/langchain_google_genai/chat_models.py:1089, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    1063 def _generate(
#    1064     self,
#    1065     messages: List[BaseMessage],
#    (...)   1076     **kwargs: Any,
#    1077 ) -> ChatResult:
#    1078     request = self._prepare_request(
#    1079         messages,
#    1080         stop=stop,
#    (...)   1087         tool_choice=tool_choice,
#    1088     )
# -> 1089     response: GenerateContentResponse = _chat_with_retry(
#    1090         request=request,
#    1091         **kwargs,
#    1092         generation_method=self.client.generate_content,
#    1093         metadata=self.default_metadata,
#    1094     )
#    1095     return _response_to_result(response)
#
# File ~/.pyenv/versions/3.11.11/envs/llm-application/lib/python3.11/site-packages/langchain_google_genai/chat_models.py:206, in _chat_with_retry(generation_method, **kwargs)
#     203     except Exception as e:
#     204         raise e
# --> 206 return _chat_with_retry(**kwargs)
#
# File ~/.pyenv/versions/3.11.11/envs/llm-application/lib/python3.11/site-packages/tenacity/__init__.py:338, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     336 copy = self.copy()
#     337 wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 338 return copy(f, *args, **kw)
#
# File ~/.pyenv/versions/3.11.11/envs/llm-application/lib/python3.11/site-packages/tenacity/__init__.py:477, in Retrying.__call__(self, fn, *args, **kwargs)
#     475 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     476 while True:
# --> 477     do = self.iter(retry_state=retry_state)
#     478     if isinstance(do, DoAttempt):
#     479         try:
#
# File ~/.pyenv/versions/3.11.11/envs/llm-application/lib/python3.11/site-packages/tenacity/__init__.py:378, in BaseRetrying.iter(self, retry_state)
#     376 result = None
#     377 for action in self.iter_state.actions:
# --> 378     result = action(retry_state)
#     379 return result
#
# File ~/.pyenv/versions/3.11.11/envs/llm-application/lib/python3.11/site-packages/tenacity/__init__.py:400, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     398 def _post_retry_check_actions(self, retry_state: "RetryCallState") -> None:
#     399     if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 400         self._add_action_func(lambda rs: rs.outcome.result())
#     401         return
#     403     if self.after is not None:
#
# File ~/.pyenv/versions/3.11.11/lib/python3.11/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~/.pyenv/versions/3.11.11/lib/python3.11/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/.pyenv/versions/3.11.11/envs/llm-application/lib/python3.11/site-packages/tenacity/__init__.py:480, in Retrying.__call__(self, fn, *args, **kwargs)
#     478 if isinstance(do, DoAttempt):
#     479     try:
# --> 480         result = fn(*args, **kwargs)
#     481     except BaseException:  # noqa: B902
#     482         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~/.pyenv/versions/3.11.11/envs/llm-application/lib/python3.11/site-packages/langchain_google_genai/chat_models.py:188, in _chat_with_retry.<locals>._chat_with_retry(**kwargs)
#     185 @retry_decorator
#     186 def _chat_with_retry(**kwargs: Any) -> Any:
#     187     try:
# --> 188         return generation_method(**kwargs)
#     189     # Do not retry for these errors.
#     190     except google.api_core.exceptions.FailedPrecondition as exc:
#
# File ~/.pyenv/versions/3.11.11/envs/llm-application/lib/python3.11/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py:867, in GenerativeServiceClient.generate_content(self, request, model, contents, retry, timeout, metadata)
#     864 self._validate_universe_domain()
#     866 # Send the request.
# --> 867 response = rpc(
#     868     request,
#     869     retry=retry,
#     870     timeout=timeout,
#     871     metadata=metadata,
#     872 )
#     874 # Done; return the response.
#     875 return response
#
# File ~/.pyenv/versions/3.11.11/envs/llm-application/lib/python3.11/site-packages/google/api_core/gapic_v1/method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     128 if self._compression is not None:
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File ~/.pyenv/versions/3.11.11/envs/llm-application/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py:293, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     289 target = functools.partial(func, *args, **kwargs)
#     290 sleep_generator = exponential_sleep_generator(
#     291     self._initial, self._maximum, multiplier=self._multiplier
#     292 )
# --> 293 return retry_target(
#     294     target,
#     295     self._predicate,
#     296     sleep_generator,
#     297     timeout=self._timeout,
#     298     on_error=on_error,
#     299 )
#
# File ~/.pyenv/versions/3.11.11/envs/llm-application/lib/python3.11/site-packages/google/api_core/retry/retry_unary.py:164, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     153         _retry_error_helper(
#     154             exc,
#     155             deadline,
#    (...)    161             timeout,
#     162         )
#     163         # if exception not raised, sleep before next attempt
# --> 164         time.sleep(sleep)
#     166 raise ValueError("Sleep generator stopped yielding sleep values.")
#
# KeyboardInterrupt:

# %%
ai_msg.content
# Out:
# 'LLM은 "Master of Laws"를 의미하는 영어 약어입니다. 이는 법학 석사 학위를 나타내며, 전문적인 법률 지식을 쌓고 법률 분야에서의 경력을 쌓고자 하는 학생들이 취득하는 학위입니다. LLM 학위는 각 나라의 법무사 시험 혹은 다른 법률 분야에서의 진출을 위한 지원을 받기 위해 선택할 수 있습니다.'
